# %%
import pandas as pd

# %%
df = pd.read_csv(r'../data/github_dataset.csv')

# %%
df.head()
# Out:
#        Username                      Profile URL            Country  \
# 0     yyx990803     https://github.com/yyx990803          Singapore
# 1    lucidrains    https://github.com/lucidrains      San Francisco
# 2        getify        https://github.com/getify         Austin, TX
# 3    llSourcell    https://github.com/llSourcell  San Francisco, CA
# 4  ThePrimeagen  https://github.com/ThePrimeagen      9th Ring, Vim
#
#   Repositories Count Followers Following  \
# 0                 30    102331        97
# 1                 30     44504         0
# 2                 30     44094         2
# 3                 30     36793         4
# 4                 30     36494         4
#
#                                        Top Languages Most Used Language  \
# 0                       JavaScript, TypeScript, HTML         JavaScript
# 1                                 JavaScript, Python             Python
# 2                                    JavaScript, C++         JavaScript
# ...

# %%
# deleting the unwanted columns using drop()
df.drop(['Username','Profile URL','Top Languages','Following', 'Total Forks', 'Public Gists','Bio','Public Email','Forked Repositories','Last Activity Date'], axis=1,  inplace=True)

# %%
df.head()
# Out:
#              Country Repositories Count Followers Most Used Language  \
# 0          Singapore                 30    102331         JavaScript
# 1      San Francisco                 30     44504             Python
# 2         Austin, TX                 30     44094         JavaScript
# 3  San Francisco, CA                 30     36793             Python
# 4      9th Ring, Vim                 30     36494         JavaScript
#
#   Total Stars    Account Created At Hireable  \
# 0        2980  2010-11-28T01:05:40Z      NaN
# 1       11169  2009-07-25T19:06:27Z      NaN
# 2       23441  2009-11-08T06:56:21Z     TRUE
# 3        4517  2011-12-22T09:57:32Z     TRUE
# 4        4675  2013-05-17T15:05:59Z      NaN
#
#                                        Unique Topics  \
# 0                                                NaN
# 1  robotics, audio-synthesis, denoising-diffusion...
# 2  async-patterns, observables, security, arrow-f...
# 3                                                NaN
# ...

# %%
df.to_csv('../data/cleaned_dataset_step_1.csv', index=False)
print("Cleaned dataset saved as '../data/cleaned_dataset_step_1.csv'")
# Out:
# Cleaned dataset saved as '../data/cleaned_dataset_step_1.csv'
